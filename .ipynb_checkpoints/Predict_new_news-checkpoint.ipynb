# %%
import pandas as pd
import pickle
import re
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv("new_news.csv", names=['title', 'content'])

# %%
df.fillna('', inplace=True)

# %%
df
# Out:
#                                                 title  \
# 0   Liverpool vs Bologna: LIVE Stream and Score Up...
# 1   Boko Haram And ISWAP: Bloodshed And Rivalry - ...
# 2   AMD’s Ryzen 5000 processors with integrated gr...
# 3   Amnesty Demands Probe Into Egypt Army ‘Executi...
# 4   Laptops: What you need to know before you buy ...
# 5   Who are authorized persons outside of residenc...
# 6   'Uncaring' mum and boyfriend found guilty of k...
# 7   Pokémon Go's most prominent players call for N...
# 8        Inflation slows to 4% in July - Philstar.com
# 9   Nintendo's profit misses estimates - Taipei Times
# 10  The photo that has come to define Turkey’s wil...
# 11  Coronavirus: What's happening in Canada and ar...
# 12  AU shares 400m COVID-19 vaccine doses to membe...
# 13  PH receives 1 million more Sinovac doses - CNN...
# 14  Climate change almost completely destabilizes ...
# 15  High Court orders two Travellers be jailed for...
# 16  Japanese scientists develop freeze-dried mouse...
# 17  Australian government to offer reparations to ...
# 18  Bournemouth beach evacuated after 'large marin...
# 19  Belarus Olympian Timanovskaya says grandmother...
#
#                                               content
# 0
# 1   A screengrab from the video showing the execut...
# 2   Not just for OEMs anymore\r\nIn April, AMD ann...
# 3   Amnesty International called Thursday for an i...
# 4   Its almost time to get back to school and coll...
# 5   The Inter-Agency Task Force on Emerging Infect...
# 6   An "uncaring" mum has been convicted alongside...
# 7   Pokémon Go's most high profile players have ca...
# 8   MANILA, Philippines — Inflation further eased ...
# 9   Nintendos profit misses estimates\r\nNintendo ...
# 10  A little boy ready for a swim stops on the edg...
# 11  The latest:\r\nSeven U.S. states with the lowe...
# 12  The African Union on Thursday began monthly sh...
# 13  Metro Manila (CNN Philippines, August 5) The c...
# 14  Sign up for the latest news about climate chan...
# 15  THE High Court has ruled that two Travellers s...
# 16  WASHINGTON - Good news: Scientists won't have ...
# 17  Decades after being forcibly removed from thei...
# 18
# 19  media captionAthlete Krystina Timanovskaya: "I...

# %%
def clean_words(text):
    text = re.sub('[^a-zA-Z ]', '', text)
    return text

# %%
df['content'] = df['content'].apply(clean_words)

# %%
vec = pickle.load(open("vectorizer.pk",'rb'))

# %%
model = pickle.load(open("Final_model.sav",'rb'))

# %%
vec_data = vec.transform(df['content'])

# %%
probability_prediction = model.predict_proba(vec_data)

# %%
probability_prediction
# Out:
# array([[0.8439468 , 0.1560532 ],
#        [0.66526531, 0.33473469],
#        [0.86266503, 0.13733497],
#        [0.5646402 , 0.4353598 ],
#        [0.85748256, 0.14251744],
#        [0.55368025, 0.44631975],
#        [0.80583265, 0.19416735],
#        [0.64901131, 0.35098869],
#        [0.6543072 , 0.3456928 ],
#        [0.62515957, 0.37484043],
#        [0.83624296, 0.16375704],
#        [0.19124995, 0.80875005],
#        [0.45917579, 0.54082421],
#        [0.64491506, 0.35508494],
#        [0.83795144, 0.16204856],
#        [0.74507428, 0.25492572],
#        [0.69517111, 0.30482889],
#        [0.73149007, 0.26850993],
#        [0.8439468 , 0.1560532 ],
#        [0.77214815, 0.22785185]])

# %%
def label_prediction(probab):
    if len(probab) < 2:
        return "Cannot determine"
    if probab[0] >0.8:
        return "Highly Likely True"
    elif probab[0] >0.6:
        return "Likely True"
    elif probab[0] > 0.4:
        return "Cannot determine"
    elif probab[0] > 0.2:
        return "Likely False"
    else:
        return "Highly Likely False"

# %%
df['prediction'] = list(map(label_prediction, probability_prediction))

# %%
df
# Out:
#                                                 title  \
# 0   Liverpool vs Bologna: LIVE Stream and Score Up...
# 1   Boko Haram And ISWAP: Bloodshed And Rivalry - ...
# 2   AMD’s Ryzen 5000 processors with integrated gr...
# 3   Amnesty Demands Probe Into Egypt Army ‘Executi...
# 4   Laptops: What you need to know before you buy ...
# 5   Who are authorized persons outside of residenc...
# 6   'Uncaring' mum and boyfriend found guilty of k...
# 7   Pokémon Go's most prominent players call for N...
# 8        Inflation slows to 4% in July - Philstar.com
# 9   Nintendo's profit misses estimates - Taipei Times
# 10  The photo that has come to define Turkey’s wil...
# 11  Coronavirus: What's happening in Canada and ar...
# 12  AU shares 400m COVID-19 vaccine doses to membe...
# 13  PH receives 1 million more Sinovac doses - CNN...
# 14  Climate change almost completely destabilizes ...
# 15  High Court orders two Travellers be jailed for...
# 16  Japanese scientists develop freeze-dried mouse...
# 17  Australian government to offer reparations to ...
# 18  Bournemouth beach evacuated after 'large marin...
# 19  Belarus Olympian Timanovskaya says grandmother...
#
#                                               content           prediction
# 0                                                       Highly Likely True
# 1   A screengrab from the video showing the execut...          Likely True
# 2   Not just for OEMs anymoreIn April AMD announce...   Highly Likely True
# 3   Amnesty International called Thursday for an i...     Cannot determine
# 4   Its almost time to get back to school and coll...   Highly Likely True
# 5   The InterAgency Task Force on Emerging Infecti...     Cannot determine
# 6   An uncaring mum has been convicted alongside h...   Highly Likely True
# 7   Pokmon Gos most high profile players have call...          Likely True
# 8   MANILA Philippines  Inflation further eased in...          Likely True
# 9   Nintendos profit misses estimatesNintendo Co h...          Likely True
# 10  A little boy ready for a swim stops on the edg...   Highly Likely True
# 11  The latestSeven US states with the lowest COVI...  Highly Likely False
# 12  The African Union on Thursday began monthly sh...     Cannot determine
# 13  Metro Manila CNN Philippines August  The count...          Likely True
# 14  Sign up for the latest news about climate chan...   Highly Likely True
# 15  THEHigh Court has ruled that two Travellerssho...          Likely True
# 16  WASHINGTON  Good news Scientists wont have to ...          Likely True
# 17  Decades after being forcibly removed from thei...          Likely True
# 18                                                      Highly Likely True
# 19  media captionAthlete Krystina Timanovskaya Its...          Likely True
